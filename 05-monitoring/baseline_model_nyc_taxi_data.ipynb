# %% [markdown]
# # Baseline model for batch monitoring example

# %%
import requests
import datetime
import pandas as pd

from joblib import load, dump
from tqdm import tqdm

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# %%
files = [('green_tripdata_2022-02.parquet', './data'), ('green_tripdata_2022-01.parquet', './data')]

print("Download files:")
for file, path in files:
    url=f"https://d37ci6vzurychx.cloudfront.net/trip-data/{file}"
    resp=requests.get(url, stream=True)
    save_path=f"{path}/{file}"
    with open(save_path, "wb") as handle:
        for data in tqdm(resp.iter_content(),
                        desc=f"{file}",
                        postfix=f"save to {save_path}",
                        total=int(resp.headers["Content-Length"])):
            handle.write(data)
# Out:
# Download files:
# green_tripdata_2022-02.parquet: 100%|█| 1428262/1428262 [00:10<00:00, 135034.50it/s, save to ./data/green_tripdata_2022-02.
# green_tripdata_2022-01.parquet: 100%|█| 1254291/1254291 [00:09<00:00, 135256.75it/s, save to ./data/green_tripdata_2022-01.

# %%
jan_data = pd.read_parquet('data/green_tripdata_2022-01.parquet')

# %%
jan_data.describe()
# Out:
#            VendorID        lpep_pickup_datetime       lpep_dropoff_datetime  \
# count  62495.000000                       62495                       62495
# mean       1.849508  2022-01-16 14:18:36.026354  2022-01-16 14:37:37.189551
# min        1.000000         2009-01-01 00:34:01         2009-01-01 17:05:20
# 25%        2.000000         2022-01-08 23:41:50  2022-01-08 23:55:28.500000
# 50%        2.000000         2022-01-16 15:59:42         2022-01-16 16:17:00
# 75%        2.000000         2022-01-24 09:16:50         2022-01-24 09:37:28
# max        2.000000         2022-01-31 23:57:37         2022-02-01 21:01:54
# std        0.357556                         NaN                         NaN
#
#          RatecodeID  PULocationID  DOLocationID  passenger_count  \
# count  56200.000000  62495.000000  62495.000000     56200.000000
# mean       1.198719     97.615041    135.969902         1.258399
# min        1.000000      1.000000      1.000000         0.000000
# 25%        1.000000     55.000000     74.000000         1.000000
# 50%        1.000000     75.000000    137.000000         1.000000
# 75%        1.000000    130.000000    215.000000         1.000000
# max        5.000000    265.000000    265.000000         8.000000
# std        0.862313     62.987311     77.590956         0.877743
#
#        trip_distance   fare_amount        extra       mta_tax    tip_amount  \
# count   62495.000000  62495.000000  62495.00000  62495.000000  62495.000000
# mean       77.758632     13.914000      0.34756      0.426322      1.666540
# min         0.000000    -65.000000     -4.50000     -0.500000     -0.860000
# 25%         1.080000      7.000000      0.00000      0.500000      0.000000
# 50%         1.900000     10.500000      0.00000      0.500000      1.000000
# 75%         3.500000     17.000000      0.50000      0.500000      2.610000
# max    224481.380000    604.500000      4.50000      0.500000     76.770000
# std      2909.354163     12.088819      0.65781      0.181381      2.484928
#
#        tolls_amount  improvement_surcharge  total_amount  payment_type  \
# count  62495.000000           62495.000000  62495.000000  56200.000000
# mean       0.208182               0.297312     17.490532      1.403594
# min       -6.550000              -0.300000    -71.850000      1.000000
# 25%        0.000000               0.300000      9.360000      1.000000
# 50%        0.000000               0.300000     13.860000      1.000000
# 75%        0.000000               0.300000     21.050000      2.000000
# max       44.750000               0.300000    605.300000      5.000000
# std        1.257659               0.037201     13.623416      0.516316
#
#           trip_type  congestion_surcharge
# count  56200.000000          56200.000000
# mean       1.040925              0.706628
# min        1.000000              0.000000
# 25%        1.000000              0.000000
# 50%        1.000000              0.000000
# 75%        1.000000              2.750000
# max        2.000000              2.750000
# std        0.198119              1.201632

# %%
jan_data.shape
# Out:
# (62495, 20)

# %%
# create target
jan_data["duration_min"] = jan_data.lpep_dropoff_datetime - jan_data.lpep_pickup_datetime
jan_data.duration_min = jan_data.duration_min.apply(lambda td : float(td.total_seconds())/60)

# %%
# filter out outliers
jan_data = jan_data[(jan_data.duration_min >= 0) & (jan_data.duration_min <= 60)]
jan_data = jan_data[(jan_data.passenger_count > 0) & (jan_data.passenger_count <= 8)]

# %%
jan_data.duration_min.hist()
# Out:
# <AxesSubplot:>

# %%
# data labeling
target = "duration_min"
num_features = ["passenger_count", "trip_distance", "fare_amount", "total_amount"]
cat_features = ["PULocationID", "DOLocationID"]

# %%
jan_data.shape
# Out:
# (55211, 21)

# %%
train_data = jan_data[:30000]
val_data = jan_data[30000:]

# %%
model = LinearRegression()

# %%
model.fit(train_data[num_features + cat_features], train_data[target])
# Out:
# LinearRegression()

# %%
train_preds = model.predict(train_data[num_features + cat_features])
train_data['prediction'] = train_preds
# Out:
# /tmp/ipykernel_2695/3810346118.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['prediction'] = train_preds

# %%
val_preds = model.predict(val_data[num_features + cat_features])
val_data['prediction'] = val_preds
# Out:
# /tmp/ipykernel_2695/3727490221.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_data['prediction'] = val_preds

# %%
print(mean_absolute_error(train_data.duration_min, train_data.prediction))
print(mean_absolute_error(val_data.duration_min, val_data.prediction))
# Out:
# 3.804665373785062
# 4.142064073688447

# %% [markdown]
# # Dump model and reference data

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    dump(model, f_out)

# %%
val_data.to_parquet('data/reference.parquet')

# %% [markdown]
# # Evidently Report

# %%
from evidently import ColumnMapping
from evidently.report import Report
from evidently.metric_preset import DataDriftPreset, TargetDriftPreset, RegressionPreset
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 from evidently import ColumnMapping
#       2 from evidently.report import Report
#       3 from evidently.metric_preset import DataDriftPreset, TargetDriftPreset, RegressionPreset
#
# ImportError: cannot import name 'ColumnMapping' from 'evidently' (/home/codespace/anaconda3/lib/python3.9/site-packages/evidently/__init__.py)

# %%
column_mapping = ColumnMapping(
    target=None,
    prediction='prediction',
    numerical_features=num_features,
    categorical_features=cat_features
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 column_mapping = ColumnMapping(
#       2     target=None,
#       3     prediction='prediction',
#       4     numerical_features=num_features,
#       5     categorical_features=cat_features
#       6 )
#
# NameError: name 'ColumnMapping' is not defined

# %%
report = Report(metrics=[
    ColumnDriftMetric(column_name='prediction'),
    DatasetDriftMetric(),
    DatasetMissingValuesMetric()
]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 report = Report(metrics=[
#       2     ColumnDriftMetric(column_name='prediction'),
#       3     DatasetDriftMetric(),
#       4     DatasetMissingValuesMetric()
#       5 ]
#       6 )
#
# NameError: name 'Report' is not defined

# %%
report.run(reference_data=train_data, current_data=val_data, column_mapping=column_mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 report.run(reference_data=train_data, current_data=val_data, column_mapping=column_mapping)
#
# NameError: name 'report' is not defined

# %%
report.show(mode='inline')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 report.show(mode='inline')
#
# NameError: name 'report' is not defined

# %%
result = report.as_dict()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 result = report.as_dict()
#
# NameError: name 'report' is not defined

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
#prediction drift
result['metrics'][0]['result']['drift_score']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 2>()
#       1 #prediction drift
# ----> 2 result['metrics'][0]['result']['drift_score']
#
# NameError: name 'result' is not defined

# %%
#number of drifted columns
result['metrics'][1]['result']['number_of_drifted_columns']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [47], in <cell line: 2>()
#       1 #number of drifted columns
# ----> 2 result['metrics'][1]['result']['number_of_drifted_columns']
#
# NameError: name 'result' is not defined

# %%
#share of missing values
result['metrics'][2]['result']['current']['share_of_missing_values']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 2>()
#       1 #share of missing values
# ----> 2 result['metrics'][2]['result']['current']['share_of_missing_values']
#
# NameError: name 'result' is not defined

# %% [markdown]
# # Evidently Dashboard

# %%
from evidently.metric_preset import DataDriftPreset, DataQualityPreset

from evidently.ui.workspace import Workspace
from evidently.ui.dashboards import DashboardPanelCounter, DashboardPanelPlot, CounterAgg, PanelValue, PlotType, ReportFilter
from evidently.renderers.html_widgets import WidgetSize
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 from evidently.metric_preset import DataDriftPreset, DataQualityPreset
#       3 from evidently.ui.workspace import Workspace
#       4 from evidently.ui.dashboards import DashboardPanelCounter, DashboardPanelPlot, CounterAgg, PanelValue, PlotType, ReportFilter
#
# ModuleNotFoundError: No module named 'evidently.metric_preset'

# %%
ws = Workspace("workspace")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 ws = Workspace("workspace")
#
# NameError: name 'Workspace' is not defined

# %%
project = ws.create_project("NYC Taxi Data Quality Project")
project.description = "My project descriotion"
project.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 project = ws.create_project("NYC Taxi Data Quality Project")
#       2 project.description = "My project descriotion"
#       3 project.save()
#
# NameError: name 'ws' is not defined

# %%
regular_report = Report(
    metrics=[
        DataQualityPreset()
    ],
    timestamp=datetime.datetime(2022,1,28)
)

regular_report.run(reference_data=None,
                  current_data=val_data.loc[val_data.lpep_pickup_datetime.between('2022-01-28', '2022-01-29', inclusive="left")],
                  column_mapping=column_mapping)

regular_report
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
# ----> 1 regular_report = Report(
#       2     metrics=[
#       3         DataQualityPreset()
#       4     ],
#       5     timestamp=datetime.datetime(2022,1,28)
#       6 )
#       8 regular_report.run(reference_data=None,
#       9                   current_data=val_data.loc[val_data.lpep_pickup_datetime.between('2022-01-28', '2022-01-29', inclusive="left")],
#      10                   column_mapping=column_mapping)
#      12 regular_report
#
# NameError: name 'Report' is not defined

# %%
ws.add_report(project.id, regular_report)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 ws.add_report(project.id, regular_report)
#
# NameError: name 'ws' is not defined

# %%
#configure the dashboard
project.dashboard.add_panel(
    DashboardPanelCounter(
        filter=ReportFilter(metadata_values={}, tag_values=[]),
        agg=CounterAgg.NONE,
        title="NYC taxi data dashboard"
    )
)

project.dashboard.add_panel(
    DashboardPanelPlot(
        filter=ReportFilter(metadata_values={}, tag_values=[]),
        title="Inference Count",
        values=[
            PanelValue(
                metric_id="DatasetSummaryMetric",
                field_path="current.number_of_rows",
                legend="count"
            ),
        ],
        plot_type=PlotType.BAR,
        size=WidgetSize.HALF,
    ),
)

project.dashboard.add_panel(
    DashboardPanelPlot(
        filter=ReportFilter(metadata_values={}, tag_values=[]),
        title="Number of Missing Values",
        values=[
            PanelValue(
                metric_id="DatasetSummaryMetric",
                field_path="current.number_of_missing_values",
                legend="count"
            ),
        ],
        plot_type=PlotType.LINE,
        size=WidgetSize.HALF,
    ),
)

project.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [54], in <cell line: 2>()
#       1 #configure the dashboard
# ----> 2 project.dashboard.add_panel(
#       3     DashboardPanelCounter(
#       4         filter=ReportFilter(metadata_values={}, tag_values=[]),
#       5         agg=CounterAgg.NONE,
#       6         title="NYC taxi data dashboard"
#       7     )
#       8 )
#      10 project.dashboard.add_panel(
#      11     DashboardPanelPlot(
#      12         filter=ReportFilter(metadata_values={}, tag_values=[]),
#    (...)
#      23     ),
#      24 )
#      26 project.dashboard.add_panel(
#      27     DashboardPanelPlot(
#      28         filter=ReportFilter(metadata_values={}, tag_values=[]),
#    (...)
#      39     ),
#      40 )
#
# NameError: name 'project' is not defined

# %%
regular_report = Report(
    metrics=[
        DataQualityPreset()
    ],
    timestamp=datetime.datetime(2022,1,29)
)

regular_report.run(reference_data=None,
                  current_data=val_data.loc[val_data.lpep_pickup_datetime.between('2022-01-29', '2022-01-30', inclusive="left")],
                  column_mapping=column_mapping)

regular_report
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 regular_report = Report(
#       2     metrics=[
#       3         DataQualityPreset()
#       4     ],
#       5     timestamp=datetime.datetime(2022,1,29)
#       6 )
#       8 regular_report.run(reference_data=None,
#       9                   current_data=val_data.loc[val_data.lpep_pickup_datetime.between('2022-01-29', '2022-01-30', inclusive="left")],
#      10                   column_mapping=column_mapping)
#      12 regular_report
#
# NameError: name 'Report' is not defined

# %%
ws.add_report(project.id, regular_report)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 ws.add_report(project.id, regular_report)
#
# NameError: name 'ws' is not defined
