# %%
import mlflow


mlflow.set_tracking_uri("http://127.0.0.1:5002")

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'http://127.0.0.1:5002'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='mlflow-artifacts:/0', creation_time=1756536788405, experiment_id='0', last_update_time=1756536788405, lifecycle_stage='active', name='Default', tags={}>]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

mlflow.set_experiment("my-experiment-1")

with mlflow.start_run():

    X, y = load_iris(return_X_y=True)

    params = {"C": 0.1, "random_state": 42}
    mlflow.log_params(params)

    lr = LogisticRegression(**params).fit(X, y)
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))

    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# 2025/08/30 06:54:28 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# 2025/08/30 06:54:28 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/08/30 06:54:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# default artifacts URI: 'mlflow-artifacts:/1/63669c664ccc45579f797b5fda2e5c88/artifacts'
# 🏃 View run bittersweet-bee-342 at: http://127.0.0.1:5002/#/experiments/1/runs/63669c664ccc45579f797b5fda2e5c88
# 🧪 View experiment at: http://127.0.0.1:5002/#/experiments/1

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1756536868166, experiment_id='1', last_update_time=1756536868166, lifecycle_stage='active', name='my-experiment-1', tags={}>,
#  <Experiment: artifact_location='mlflow-artifacts:/0', creation_time=1756536788405, experiment_id='0', last_update_time=1756536788405, lifecycle_stage='active', name='Default', tags={}>]

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient("http://127.0.0.1:5002")

# %%
client.search_registered_models()
# Out:
# []

# %%
run_id = client.search_runs(experiment_ids='1')[0].info.run_id
mlflow.register_model(
    model_uri=f"runs:/{run_id}/models",
    name='iris-classifier'
)
# Out:
# Successfully registered model 'iris-classifier'.
# 2025/08/30 06:56:08 WARNING mlflow.tracking._model_registry.fluent: Run with id 63669c664ccc45579f797b5fda2e5c88 has no artifacts at artifact path 'models', registering model based on models:/m-fe30617069fc462bacc7d227642515c4 instead
# 2025/08/30 06:56:08 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: iris-classifier, version 1
# Created version '1' of model 'iris-classifier'.
# <ModelVersion: aliases=[], creation_timestamp=1756536968665, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1756536968665, metrics=None, model_id=None, name='iris-classifier', params=None, run_id='63669c664ccc45579f797b5fda2e5c88', run_link='', source='models:/m-fe30617069fc462bacc7d227642515c4', status='READY', status_message=None, tags={}, user_id='', version='1'>

# %%
client.search_registered_models()
# Out:
# [<RegisteredModel: aliases={}, creation_timestamp=1756536968584, deployment_job_id='', deployment_job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', description='', last_updated_timestamp=1756536968665, latest_versions=[<ModelVersion: aliases=[], creation_timestamp=1756536968665, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1756536968665, metrics=None, model_id=None, name='iris-classifier', params=None, run_id='63669c664ccc45579f797b5fda2e5c88', run_link='', source='models:/m-fe30617069fc462bacc7d227642515c4', status='READY', status_message=None, tags={}, user_id='', version='1'>], name='iris-classifier', tags={}>]
